# %%
from google_nlp import GoogleNLP

# %%
g = GoogleNLP({})

# %%
r = g.predict('this is text')
# Out:
# {'classify_text': document_sentiment {
#   magnitude: 0.10000000149
#   score: 0.10000000149
# }
# language: "en"
# sentences {
#   text {
#     content: "this is text"
#     begin_offset: -1
#   }
#   sentiment {
#     magnitude: 0.10000000149
#     score: 0.10000000149
#   }
# }
# , 'analyze_syntax': document_sentiment {
#   magnitude: 0.10000000149
#   score: 0.10000000149
# }
# language: "en"
# sentences {
#   text {
#     content: "this is text"
#     begin_offset: -1
#   }
#   sentiment {
#     magnitude: 0.10000000149
#     score: 0.10000000149
#   }
# }
# , 'annotate_text': document_sentiment {
#   magnitude: 0.10000000149
#   score: 0.10000000149
# }
# language: "en"
# sentences {
#   text {
#     content: "this is text"
#     begin_offset: -1
#   }
#   sentiment {
#     magnitude: 0.10000000149
#     score: 0.10000000149
#   }
# }
# , 'analyze_entity_sentiment': document_sentiment {
#   magnitude: 0.10000000149
#   score: 0.10000000149
# }
# language: "en"
# sentences {
# ...

# %%
r
# Out:
# {'analyze_entities': document_sentiment {
#    magnitude: 0.10000000149
#    score: 0.10000000149
#  }
#  language: "en"
#  sentences {
#    text {
#      content: "this is text"
#      begin_offset: -1
#    }
#    sentiment {
#      magnitude: 0.10000000149
#      score: 0.10000000149
#    }
#  }, 'analyze_entity_sentiment': document_sentiment {
#    magnitude: 0.10000000149
#    score: 0.10000000149
#  }
#  language: "en"
#  sentences {
#    text {
#      content: "this is text"
#      begin_offset: -1
#    }
#    sentiment {
#      magnitude: 0.10000000149
#      score: 0.10000000149
#    }
#  }, 'analyze_sentiment': document_sentiment {
#    magnitude: 0.10000000149
#    score: 0.10000000149
#  }
#  language: "en"
#  sentences {
#    text {
#      content: "this is text"
#      begin_offset: -1
#    }
#    sentiment {
#      magnitude: 0.10000000149
#      score: 0.10000000149
#    }
#  }, 'analyze_syntax': document_sentiment {
#    magnitude: 0.10000000149
# ...
